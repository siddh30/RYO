# %% [markdown]
# # RYO — Agent Test Notebook
# Test the `run_ceo()` entry point against the Claude Agent SDK.

# %%
import sys
sys.path.append('..')

import asyncio
from agents.ceo import run_ceo

# %%
# Test news query
response = asyncio.run(run_ceo("What's the latest in AI news today?"))
print(response)

# %%
# Test search / weather
response = asyncio.run(run_ceo("What's the weather in Jersey City right now?"))
print(response)

# %%
# Test memory store
response = asyncio.run(run_ceo("Remember that I prefer dark mode in all my apps."))
print(response)

# %%
# Test memory delete
response = asyncio.run(run_ceo("Forget the dark mode preference you just saved."))
print(response)

# %%
# Free-form test
user_input = "What are the top 3 finance headlines this week?"
response = asyncio.run(run_ceo(user_input))
print(response)
